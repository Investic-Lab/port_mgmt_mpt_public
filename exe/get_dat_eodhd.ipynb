# %%
import os
import pickle
import yfinance as yf
import pandas as pd

# %%
""" Get data from Dow Jones 30 """

# Define your API token (replace with your actual token)
api_token = '63b645f5306f34.00714086'

# Define the output directory if it doesn't exist
output_dir = '../dat_eodhd_dow30/'
os.makedirs(output_dir, exist_ok=True)

# For Dow Jones 30
tickers = get_ticker(file_name='dow30')

for ticker in tickers:
    ticker = ticker.replace(".", "")
    response = fetch_stock_data(symbol=f'{ticker}.US', api_token=api_token, from_date='2000-01-01')
    if response.status_code == 200:
        data = response.json()
        df = pd.DataFrame(data)
        df['date'] = pd.to_datetime(df['date'])
        df.set_index('date', inplace=True)
        
        with open(os.path.join(output_dir, f'{ticker}.pkl'), 'wb') as f:
            pickle.dump(df, f)
    else:
        print(f"Failed to retrieve data for {ticker}")

# %%
""" Get data from Nasdaq 100 """

# Define your API token (replace with your actual token)
api_token = '63b645f5306f34.00714086'

# Define the output directory if it doesn't exist
output_dir = '../dat_eodhd_nasdaq100/'
os.makedirs(output_dir, exist_ok=True)

# For Dow Jones 30
tickers = get_ticker(file_name='nasdaq100')

for ticker in tickers:
    ticker = ticker.replace(".", "")
    response = fetch_stock_data(symbol=f'{ticker}.US', api_token=api_token, from_date='2000-01-01')
    if response.status_code == 200:
        data = response.json()
        df = pd.DataFrame(data)
        df['date'] = pd.to_datetime(df['date'])
        df.set_index('date', inplace=True)
        
        with open(os.path.join(output_dir, f'{ticker}.pkl'), 'wb') as f:
            pickle.dump(df, f)
    else:
        print(f"Failed to retrieve data for {ticker}")

# %%
""" Get data from S&P500 - BigCap """

# Define your API token (replace with your actual token)
api_token = '63b645f5306f34.00714086'

# Define the output directory if it doesn't exist
output_dir = '../dat_eodhd_sp500/'
os.makedirs(output_dir, exist_ok=True)

# For Dow Jones 30
tickers = get_ticker(file_name='sp500')

for ticker in tickers:
    ticker = ticker.replace(".", "")
    response = fetch_stock_data(symbol=f'{ticker}.US', api_token=api_token, from_date='2000-01-01')
    if response.status_code == 200:
        data = response.json()
        df = pd.DataFrame(data)
        df['date'] = pd.to_datetime(df['date'])
        df.set_index('date', inplace=True)
        
        with open(os.path.join(output_dir, f'{ticker}.pkl'), 'wb') as f:
            pickle.dump(df, f)
    else:
        print(f"Failed to retrieve data for {ticker}")

# %%
""" Get data from S&P400 - MidCap """

# Define your API token (replace with your actual token)
api_token = '63b645f5306f34.00714086'

# Define the output directory if it doesn't exist
output_dir = '../dat_eodhd_sp400/'
os.makedirs(output_dir, exist_ok=True)

# For Dow Jones 30
tickers = get_ticker(file_name='sp400')

for ticker in tickers:
    ticker = ticker.replace(".", "")
    response = fetch_stock_data(symbol=f'{ticker}.US', api_token=api_token, from_date='2000-01-01')
    if response.status_code == 200:
        data = response.json()
        df = pd.DataFrame(data)
        df['date'] = pd.to_datetime(df['date'])
        df.set_index('date', inplace=True)
        
        with open(os.path.join(output_dir, f'{ticker}.pkl'), 'wb') as f:
            pickle.dump(df, f)
    else:
        print(f"Failed to retrieve data for {ticker}")

# %%
""" Get data from S&P600 - SmallCap """

# Define your API token (replace with your actual token)
api_token = '63b645f5306f34.00714086'

# Define the output directory if it doesn't exist
output_dir = '../dat_eodhd_sp600/'
os.makedirs(output_dir, exist_ok=True)

# For Dow Jones 30
tickers = get_ticker(file_name='sp600')

for ticker in tickers:
    ticker = ticker.replace(".", "")
    response = fetch_stock_data(symbol=f'{ticker}.US', api_token=api_token, from_date='2000-01-01')
    if response.status_code == 200:
        data = response.json()
        df = pd.DataFrame(data)
        df['date'] = pd.to_datetime(df['date'])
        df.set_index('date', inplace=True)
        
        with open(os.path.join(output_dir, f'{ticker}.pkl'), 'wb') as f:
            pickle.dump(df, f)
    else:
        print(f"Failed to retrieve data for {ticker}")
